# %%
import numpy as np
import scipy as scp
import pandas as pd
from matplotlib import pyplot as plt
from scipy.optimize import curve_fit
from scipy.stats import norm
from scipy.special import erf
from datetime import datetime
import h5py, math

# %%
x = [325.0, 1033.5, 2047.0, 3074.3, 4058.8, 5050.3, 6103.7, 7063.2, 8063.6, 9087.1, 10277.5, 11063.0, 11990.0, 13029.4, 14032.9, 15204.3]
y = [10224.77, 10331.43, 19465.48, 46082.30, 79286.42, 119170.52, 166417.27, 211048.65, 256269.98, 299004.57, 340775.60, 360316.03, 351215.85, 291115.73, 232519.42, 170402.42]
yerr = [13.05, 13.12, 18.01, 27.71, 36.35, 44.57, 52.67, 59.31, 65.35, 70.59, 75.36, 77.49, 76.51, 69.66, 62.25, 53.29]

if len(x) != len(y) or len(x) != len(yerr) :
    print("Error: Missing values")
     

plt.figure(figsize=(8,5))
plt.errorbar(x, y, yerr=yerr, fmt='o', capsize=3, label='Data')

plt.legend()
plt.xlabel("Switcher Motor Position [A.U.]")
plt.ylabel("rate [cps]")
plt.title("EDM rate vs. switcher position")
plt.grid(True)
plt.show()
